# %%
import sleap_io as sio

# %%
labels = sio.load_slp("/Users/divyasesh/Desktop/talmolab/sleap/tests/data/models/minimal_instance.UNet.bottomup/labels_gt.val.slp")
labels
# Out:
# Labels(labeled_frames=1, videos=1, skeletons=1, tracks=0, suggestions=0, sessions=0)

# %%
pred_labels = sio.load_slp("/Users/divyasesh/Desktop/talmolab/sleap/tests/data/models/minimal_instance.UNet.bottomup/labels_pr.val.slp")
pred_labels
# Out:
# Labels(labeled_frames=1, videos=1, skeletons=1, tracks=0, suggestions=0, sessions=0)

# %%
merge = labels.merge(pred_labels)
merge
# Out:
# MergeResult(successful=True, frames_merged=1, instances_added=0, instances_updated=0, instances_skipped=0, conflicts=[ConflictResolution(frame=LabeledFrame(video=Video(filename="tests/data/json_format_v1/centered_pair_low_quality.mp4", shape=(1100, 384, 384, 1), backend=MediaVideo), frame_idx=0, instances=[Instance(points=[[92.65220773208894, 202.7259777426982], [152.34188115939048, 158.42364351243816]], track=None), Instance(points=[[205.9300539013689, 187.88964024221963], [278.63521449272383, 203.3658657346604]], track=None)]), conflict_type='instance_conflict', original_data=Instance(points=[[205.9300539013689, 187.88964024221963], [278.63521449272383, 203.3658657346604]], track=None), new_data=PredictedInstance(points=[[205.57424926757812, 188.81106567382812], [278.7353515625, 204.41049194335938]], track=None, score=1.00, tracking_score=0.00), resolution='kept_user'), ConflictResolution(frame=LabeledFrame(video=Video(filename="tests/data/json_format_v1/centered_pair_low_quality.m
# ...

# %%
merge.successful
# Out:
# True

# %%
merge.conflicts
# Out:
# [ConflictResolution(frame=LabeledFrame(video=Video(filename="tests/data/json_format_v1/centered_pair_low_quality.mp4", shape=(1100, 384, 384, 1), backend=MediaVideo), frame_idx=0, instances=[Instance(points=[[92.65220773208894, 202.7259777426982], [152.34188115939048, 158.42364351243816]], track=None), Instance(points=[[205.9300539013689, 187.88964024221963], [278.63521449272383, 203.3658657346604]], track=None)]), conflict_type='instance_conflict', original_data=Instance(points=[[205.9300539013689, 187.88964024221963], [278.63521449272383, 203.3658657346604]], track=None), new_data=PredictedInstance(points=[[205.57424926757812, 188.81106567382812], [278.7353515625, 204.41049194335938]], track=None, score=1.00, tracking_score=0.00), resolution='kept_user'),
# ...
